# %%
import numpy as np
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets

# %%
from hopkins import *
from metric import *
from visual_assessment_of_tendency import *

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
iris = datasets.load_iris()
clust1 = scale(iris.data)
clust2 = scale(np.random.rand(150, 4))

# %%
# Elbow graphic
inertia = []
for i in range(1, 8):
    kmeans = KMeans(n_clusters=i, n_init='auto', random_state=0).fit(clust1)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 8), inertia, marker='o')
plt.title('Elbow')
plt.show()

# %%
inertia
# Out:
# [600.0000000000001,
#  222.36170496502305,
#  139.82049635974982,
#  114.0925469040309,
#  90.80759161913358,
#  81.50473906581257,
#  72.8210396242572]

# %%
# Elbow graphic
inertia = []
for i in range(1, 8):
    kmeans = KMeans(n_clusters=i, n_init='auto', random_state=0).fit(clust2)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 8), inertia, marker='o')
plt.title('Elbow')
plt.show()

# %%
hopkins(clust1, 150)
# Out:
# np.float64(0.18015553508637996)

# %%
hopkins(clust2, 150)
# Out:
# np.float64(0.5052830734017438)

# %%
vat(clust1)

# %%
vat(clust2)

# %%
ivat(clust1)

# %%
ivat(clust2)

# %%
m = assess_tendency_by_metric(clust1, 'silhouette', 5)

# %%
print(m)
# Out:
# (np.int64(2), array([0.58175005, 0.45994824, 0.41308512, 0.39701897]))

# %%
m = assess_tendency_by_metric(clust1, 'davies_bouldin', 5)
m
# Out:
# (np.int64(2), array([0.59331269, 0.83359495, 0.869779  , 0.92544306]))

# %%
m = assess_tendency_by_metric(clust1, 'calinski_harabasz', 5)
m
# Out:
# (np.int64(2), array([251.34933946, 241.42632349, 206.07292962, 201.27311906]))

# %%
m = assess_tendency_by_metric(clust2, 'davies_bouldin', 5)
m
# Out:
# (np.int64(4), array([1.89985717, 1.58513435, 1.36700573, 1.39952184]))

# %%
m = assess_tendency_by_metric(clust2, 'davies_bouldin', 5)
m
# Out:
# (np.int64(5), array([1.89699596, 1.5352104 , 1.45939552, 1.32171294]))

# %%
m = assess_tendency_by_metric(clust2, 'calinski_harabasz', 5)
m
# Out:
# (np.int64(2), array([40.04728964, 36.01741033, 32.09340384, 36.12299288]))

# %%
m = assess_tendency_by_mean_metric_score(clust1, 5)
m
# Out:
# np.float64(2.0)

# %%
m = assess_tendency_by_mean_metric_score(clust2, 5)
m
# Out:
# np.float64(4.0)
