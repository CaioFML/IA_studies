# %%
import numpy as np
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets

# %%
from hopkins import *
from metric import *
from visual_assessment_of_tendency import *

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
iris = datasets.load_iris()
clust1 = scale(iris.data)
clust2 = scale(np.random.rand(150, 4))

# %%
# Elbow graphic
inertia = []
for i in range(1, 8):
    kmeans = KMeans(n_clusters=i, n_init='auto', random_state=0).fit(clust1)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 8), inertia, marker='o')
plt.title('Elbow')
plt.show()

# %%
inertia
# Out:
# [600.0000000000001,
#  222.36170496502305,
#  139.82049635974982,
#  114.0925469040309,
#  90.80759161913358,
#  81.50473906581257,
#  72.8210396242572]

# %%
# Elbow graphic
inertia = []
for i in range(1, 8):
    kmeans = KMeans(n_clusters=i, n_init='auto', random_state=0).fit(clust2)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 8), inertia, marker='o')
plt.title('Elbow')
plt.show()
